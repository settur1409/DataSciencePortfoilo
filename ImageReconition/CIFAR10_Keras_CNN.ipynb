# %%
from keras.datasets import cifar10
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print("Dimensions of x_train data::", x_train.shape)
print("Dimensions of y_train data::", y_train.shape)

print("Dimensions of x_test data::", x_test.shape)
print("Dimensions of y_test data::", y_test.shape)
# Out:
# Using TensorFlow backend.
# Dimensions of x_train data:: (50000, 32, 32, 3)
# Dimensions of y_train data:: (50000, 1)
# Dimensions of x_test data:: (10000, 32, 32, 3)
# Dimensions of y_test data:: (10000, 1)

# %%
# preview the images first
train_filter = np.where(y_train == 1 )
X1_train, Y1_train = x_train[train_filter, ], y_train[train_filter, ]
print("Dimensions of X1_train data::", X1_train[0].shape)

X1_train = X1_train.reshape(10000, 32, 32, 3).transpose(0,2,3,1).astype("uint8")
plt.figure(figsize=(15,10))
x, y = 10, 4
for i in range(10):  
    plt.subplot(y, x, i+1)
    plt.imshow(X1_train[i].reshape(32, 3, 32).transpose(2,0,1),interpolation='nearest')
plt.show()
print("Dimensions of X1_train data::", X1_train[0].shape)

# %%
train_filter = np.where(y_train == 2 )
X1_train, Y1_train = x_train[train_filter, ], y_train[train_filter, ]
print("Dimensions of X1_train data::", X1_train[0].shape)

X1_train = X1_train.reshape(10000, 32, 32, 3).transpose(0,2,3,1).astype("uint8")
plt.figure(figsize=(15,10))
x, y = 10, 4
for i in range(10):  
    plt.subplot(y, x, i+1)
    plt.imshow(X1_train[i].reshape(32, 3, 32).transpose(2,0,1),interpolation='nearest')
plt.show()
print("Dimensions of X1_train data::", X1_train[0].shape)

# %%
train_filter = np.where(y_train == 3 )
X1_train, Y1_train = x_train[train_filter, ], y_train[train_filter, ]
print("Dimensions of X1_train data::", X1_train[0].shape)

X1_train = X1_train.reshape(10000, 32, 32, 3).transpose(0,2,3,1).astype("uint8")
plt.figure(figsize=(15,10))
x, y = 10, 4
for i in range(10):  
    plt.subplot(y, x, i+1)
    plt.imshow(X1_train[i].reshape(32, 3, 32).transpose(2,0,1),interpolation='nearest')
plt.show()
print("Dimensions of X1_train data::", X1_train[0].shape)

# %%
train_filter = np.where(y_train == 4 )
X1_train, Y1_train = x_train[train_filter, ], y_train[train_filter, ]
print("Dimensions of X1_train data::", X1_train[0].shape)

X1_train = X1_train.reshape(10000, 32, 32, 3).transpose(0,2,3,1).astype("uint8")
plt.figure(figsize=(15,10))
x, y = 10, 4
for i in range(10):  
    plt.subplot(y, x, i+1)
    plt.imshow(X1_train[i].reshape(32, 3, 32).transpose(2,0,1),interpolation='nearest')
plt.show()
print("Dimensions of X1_train data::", X1_train[0].shape)

# %%
train_filter = np.where(y_train == 5 )
X1_train, Y1_train = x_train[train_filter, ], y_train[train_filter, ]
print("Dimensions of X1_train data::", X1_train[0].shape)

X1_train = X1_train.reshape(10000, 32, 32, 3).transpose(0,2,3,1).astype("uint8")
plt.figure(figsize=(15,10))
x, y = 10, 4
for i in range(10):  
    plt.subplot(y, x, i+1)
    plt.imshow(X1_train[i].reshape(32, 3, 32).transpose(2,0,1),interpolation='nearest')
plt.show()
print("Dimensions of X1_train data::", X1_train[0].shape)

# %%
train_filter = np.where(y_train == 6 )
X1_train, Y1_train = x_train[train_filter, ], y_train[train_filter, ]
print("Dimensions of X1_train data::", X1_train[0].shape)

X1_train = X1_train.reshape(10000, 32, 32, 3).transpose(0,2,3,1).astype("uint8")
plt.figure(figsize=(15,10))
x, y = 10, 4
for i in range(10):  
    plt.subplot(y, x, i+1)
    plt.imshow(X1_train[i].reshape(32, 3, 32).transpose(2,0,1),interpolation='nearest')
plt.show()
print("Dimensions of X1_train data::", X1_train[0].shape)

# %%
train_filter = np.where(y_train == 7 )
X1_train, Y1_train = x_train[train_filter, ], y_train[train_filter, ]
print("Dimensions of X1_train data::", X1_train[0].shape)

X1_train = X1_train.reshape(10000, 32, 32, 3).transpose(0,2,3,1).astype("uint8")
plt.figure(figsize=(15,10))
x, y = 10, 4
for i in range(10):  
    plt.subplot(y, x, i+1)
    plt.imshow(X1_train[i].reshape(32, 3, 32).transpose(2,0,1),interpolation='nearest')
plt.show()
print("Dimensions of X1_train data::", X1_train[0].shape)

# %%
train_filter = np.where(y_train == 8 )
X1_train, Y1_train = x_train[train_filter, ], y_train[train_filter, ]
print("Dimensions of X1_train data::", X1_train[0].shape)

X1_train = X1_train.reshape(10000, 32, 32, 3).transpose(0,2,3,1).astype("uint8")
plt.figure(figsize=(15,10))
x, y = 10, 4
for i in range(10):  
    plt.subplot(y, x, i+1)
    plt.imshow(X1_train[i].reshape(32, 3, 32).transpose(2,0,1),interpolation='nearest')
plt.show()
print("Dimensions of X1_train data::", X1_train[0].shape)

# %%
train_filter = np.where(y_train == 9)
X1_train, Y1_train = x_train[train_filter, ], y_train[train_filter, ]
print("Dimensions of X1_train data::", X1_train[0].shape)

X1_train = X1_train.reshape(10000, 32, 32, 3).transpose(0,2,3,1).astype("uint8")
plt.figure(figsize=(15,10))
x, y = 10, 4
for i in range(10):  
    plt.subplot(y, x, i+1)
    plt.imshow(X1_train[i].reshape(32, 3, 32).transpose(2,0,1),interpolation='nearest')
plt.show()
print("Dimensions of X1_train data::", X1_train[0].shape)

# %%
train_filter = np.where(y_train == 0)
X1_train, Y1_train = x_train[train_filter, ], y_train[train_filter, ]
print("Dimensions of X1_train data::", X1_train[0].shape)

X1_train = X1_train.reshape(10000, 32, 32, 3).transpose(0,2,3,1).astype("uint8")
plt.figure(figsize=(15,10))
x, y = 10, 4
for i in range(10):  
    plt.subplot(y, x, i+1)
    plt.imshow(X1_train[i].reshape(32, 3, 32).transpose(2,0,1),interpolation='nearest')
plt.show()
print("Dimensions of X1_train data::", X1_train[0].shape)

# %%
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Conv3D, MaxPool3D
from keras.models import Sequential
from keras.utils import np_utils
from keras.optimizers import RMSprop
from keras.losses import categorical_crossentropy
from keras import backend as K
K.set_image_dim_ordering('tf')

#input_shape = (32, 32, 3)
classes = 10

# %%
x_train.shape

# %%
cifer_model = Sequential()
cifer_model.add(Conv2D(64, kernel_size = (3,3), activation='relu',kernel_initializer='he_normal',input_shape=input_shape))
cifer_model.add(Conv2D(64, kernel_size = (3,3), activation='relu',kernel_initializer='he_normal'))
cifer_model.add(Conv2D(64, kernel_size = (3,3), activation='relu',kernel_initializer='he_normal'))
cifer_model.add(MaxPool2D(pool_size=(2,2)))
cifer_model.add(Conv2D(32, kernel_size = (3,3), activation='relu',kernel_initializer='he_normal'))
cifer_model.add(MaxPool2D(pool_size=(2,2)))
cifer_model.add(Flatten())
cifer_model.add(Dense(128, activation='relu'))
cifer_model.add(Dense(classes,activation='softmax'))

cifer_model.summary()
cifer_model.compile(loss=categorical_crossentropy,
              optimizer=RMSprop(),
              metrics=['accuracy'])

# %%
cifer_model = Sequential()
cifer_model.add(Conv3D(32, kernel_size = 3, activation='relu',kernel_initializer='he_normal',padding="same", input_shape=(32, 32, 3, 1)))
cifer_model.add(MaxPool3D(pool_size=2, padding="same"))
cifer_model.add(Conv3D(32, kernel_size = 3, activation='relu',kernel_initializer='he_normal', padding="same"))
cifer_model.add(MaxPool3D(pool_size=2, padding="same"))
cifer_model.add(Flatten())
cifer_model.add(Dense(64, activation='relu'))
cifer_model.add(Dense(classes,activation='softmax'))

cifer_model.summary()
cifer_model.compile(loss=categorical_crossentropy,
              optimizer=RMSprop(),
              metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv3d_4 (Conv3D)            (None, 32, 32, 3, 32)     896
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 16, 16, 2, 32)     0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 16, 16, 2, 32)     27680
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 8, 8, 1, 32)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                131136
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# ...
# Total params: 160,362
# ...

# %%
from sklearn.model_selection import train_test_split
y_train = np_utils.to_categorical(y_train)
x_train = x_train/255.0

x_train = x_train.reshape(-1, 32, 32, 3, 1)

sp_x_train, sp_x_val, sp_y_train, sp_y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=1234)

print("Dimensions after split::")
print(sp_x_train.shape)
print(sp_x_val.shape)
# Out:
# Dimensions after split::
# (40000, 32, 32, 3, 1)
# (10000, 32, 32, 3, 1)

# %%
fit_params = cifer_model.fit(sp_x_train, sp_y_train, validation_data=(sp_x_val, sp_y_val), epochs=10, batch_size=100)
# Out:
# WARNING:tensorflow:From /opt/conda/envs/Python36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 719s 18ms/step - loss: 1.7056 - acc: 0.3940 - val_loss: 1.4196 - val_acc: 0.4925
# Epoch 2/10
# 40000/40000 [==============================] - 713s 18ms/step - loss: 1.2448 - acc: 0.5645 - val_loss: 1.1285 - val_acc: 0.6051
# Epoch 3/10
# 40000/40000 [==============================] - 715s 18ms/step - loss: 1.0517 - acc: 0.6351 - val_loss: 1.0468 - val_acc: 0.6319
# Epoch 4/10
# 39900/40000 [============================>.] - ETA: 1s - loss: 0.9350 - acc: 0.6754
